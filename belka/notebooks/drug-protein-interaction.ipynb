# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import rdmolops
import numpy as np
from scipy.sparse import block_diag
from spektral.data import Graph, Dataset, Loader, DisjointLoader
from spektral.data import SingleLoader
from spektral.layers import GCNConv, GlobalSumPool
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
import tensorflow as tf

# %% [markdown]
# ## Feature engineering and model generation

# %%
df = pd.read_csv('../data/train_subset.tsv').head(10000)
df
# Out:
#         id                            buildingblock1_smiles  \
# 0        0  C#CC[C@@H](CC(=O)O)NC(=O)OCC1c2ccccc2-c2ccccc21
# 1        1  C#CC[C@@H](CC(=O)O)NC(=O)OCC1c2ccccc2-c2ccccc21
# 2        2  C#CC[C@@H](CC(=O)O)NC(=O)OCC1c2ccccc2-c2ccccc21
# 3        3  C#CC[C@@H](CC(=O)O)NC(=O)OCC1c2ccccc2-c2ccccc21
# 4        4  C#CC[C@@H](CC(=O)O)NC(=O)OCC1c2ccccc2-c2ccccc21
# ...    ...                                              ...
# 9995  9995  C#CC[C@@H](CC(=O)O)NC(=O)OCC1c2ccccc2-c2ccccc21
# 9996  9996  C#CC[C@@H](CC(=O)O)NC(=O)OCC1c2ccccc2-c2ccccc21
# 9997  9997  C#CC[C@@H](CC(=O)O)NC(=O)OCC1c2ccccc2-c2ccccc21
# 9998  9998  C#CC[C@@H](CC(=O)O)NC(=O)OCC1c2ccccc2-c2ccccc21
# 9999  9999  C#CC[C@@H](CC(=O)O)NC(=O)OCC1c2ccccc2-c2ccccc21
#
#      buildingblock2_smiles    buildingblock3_smiles  \
# 0     C#CCOc1ccc(CN)cc1.Cl  Br.Br.NCC1CCCN1c1cccnn1
# 1     C#CCOc1ccc(CN)cc1.Cl  Br.Br.NCC1CCCN1c1cccnn1
# 2     C#CCOc1ccc(CN)cc1.Cl  Br.Br.NCC1CCCN1c1cccnn1
# 3     C#CCOc1ccc(CN)cc1.Cl        Br.NCc1cccc(Br)n1
# 4     C#CCOc1ccc(CN)cc1.Cl        Br.NCc1cccc(Br)n1
# ...                    ...                      ...
# 9995        C=C(C)COCCN.Cl        NCCNC(=O)c1cccnc1
# 9996        C=C(C)COCCN.Cl             NCCOc1cccnc1
# 9997        C=C(C)COCCN.Cl             NCCOc1cccnc1
# 9998        C=C(C)COCCN.Cl             NCCOc1cccnc1
# 9999        C=C(C)COCCN.Cl        NCCS(=O)Cc1ccccc1
#
#                                         molecule_smiles protein_name  binds
# 0     C#CCOc1ccc(CNc2nc(NCC3CCCN3c3cccnn3)nc(N[C@@H]...         BRD4      0
# 1     C#CCOc1ccc(CNc2nc(NCC3CCCN3c3cccnn3)nc(N[C@@H]...          HSA      0
# 2     C#CCOc1ccc(CNc2nc(NCC3CCCN3c3cccnn3)nc(N[C@@H]...          sEH      0
# 3     C#CCOc1ccc(CNc2nc(NCc3cccc(Br)n3)nc(N[C@@H](CC...         BRD4      0
# 4     C#CCOc1ccc(CNc2nc(NCc3cccc(Br)n3)nc(N[C@@H](CC...          HSA      0
# ...                                                 ...          ...    ...
# 9995  C#CC[C@@H](CC(=O)N[Dy])Nc1nc(NCCNC(=O)c2cccnc2...          sEH      0
# 9996  C#CC[C@@H](CC(=O)N[Dy])Nc1nc(NCCOCC(=C)C)nc(NC...         BRD4      0
# 9997  C#CC[C@@H](CC(=O)N[Dy])Nc1nc(NCCOCC(=C)C)nc(NC...          HSA      0
# 9998  C#CC[C@@H](CC(=O)N[Dy])Nc1nc(NCCOCC(=C)C)nc(NC...          sEH      0
# 9999  C#CC[C@@H](CC(=O)N[Dy])Nc1nc(NCCOCC(=C)C)nc(NC...         BRD4      0
#
# [10000 rows x 7 columns]

# %%
# Convert SMILES to graph
from spektral.data import Graph

def mol_to_graph(mol):
    atoms = mol.GetAtoms()
    edges = [(bond.GetBeginAtomIdx(), bond.GetEndAtomIdx()) for bond in mol.GetBonds()]
    a = rdmolops.GetAdjacencyMatrix(mol)
    x = np.array([atom.GetAtomicNum() for atom in atoms]).reshape(-1, 1).astype(np.float32)  # Convert to float32 here
    return Graph(x=x, a=a)

# Convert SMILES to Graph
def smiles_to_graph(smiles):
    mol = Chem.MolFromSmiles(smiles)
    return mol_to_graph(mol) if mol else None

def pad_features(features, max_features):
    padded_length = max_features - features.shape[1]
    padded_features = np.pad(features, ((0, 0), (0, padded_length)), 'constant', constant_values=0)
    return padded_features.astype(np.float32)  # Ensure the padded array is float32

def process_df(df):
    smile_columns = ['buildingblock1_smiles', 'buildingblock2_smiles', 'buildingblock3_smiles', 'molecule_smiles']
    unified_graph_list = []
    for _, row in df.iterrows():
        graphs = [smiles_to_graph(row[col]) for col in smile_columns]
        graphs = [graph for graph in graphs if graph is not None]
        if len(graphs) == 4:
            max_features = max(graph.x.shape[1] for graph in graphs)
            combined_x = np.vstack([pad_features(graph.x, max_features) for graph in graphs])
            combined_a = block_diag([graph.a for graph in graphs]).tocoo()  # Keep adjacency matrix in COO format
            label = row['binds']  # Extract the label
            unified_graph_list.append(Graph(x=combined_x, a=combined_a, y=label))
    return unified_graph_list

# %%
import numpy as np
from scipy.sparse import csr_matrix
from spektral.data import Graph, Dataset
from tensorflow.keras.utils import to_categorical


class MoleculeDataset(Dataset):
    def __init__(self, graph_list, **kwargs):
        self.graph_list = graph_list
        super().__init__(**kwargs)
    
    def read(self):
        return self.graph_list

    def collate(batch):
        features = [item.x for item in batch]
        adj_matrices = [item.a for item in batch]
        labels = [item.y for item in batch]  # Assuming labels are included in the graph objects
    
        features = np.vstack(features)
        adj_matrices = [adj.tocoo() for adj in adj_matrices]  # Convert to COO format if not already
        adj_indices = [np.column_stack((adj.row, adj.col)) for adj in adj_matrices]
        adj_values = [adj.data for adj in adj_matrices]
        adj_shape = adj_matrices[0].shape if adj_matrices else (0, 0)
    
        # Convert to TensorFlow SparseTensor
        adj_matrices = [tf.SparseTensor(indices, values, adj_shape) for indices, values in zip(adj_indices, adj_values)]
        adj_matrices = tf.sparse.concat(axis=0, sp_inputs=adj_matrices)
    
        labels = np.array(labels)  # Ensure labels are a numpy array
    
        return [features, adj_matrices], labels
        
graphs = process_df(df)

# %%
import spektral
import tensorflow as tf
from spektral.layers import GraphSageConv, GlobalAvgPool
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense



class GNN(tf.keras.Model):
    def __init__(self, activation='relu'):
        super(GNN, self).__init__()
        self.graph_conv1 = GraphSageConv(32, activation=activation)
        self.graph_conv2 = GraphSageConv(32, activation=activation)
        self.pool = GlobalAvgPool()
        self.classifier = Dense(1, activation='sigmoid')

    def call(self, inputs):
        x, a, i = inputs
        # Pass only x and a to the GraphSageConv layers
        x = self.graph_conv1([x, a])
        x = self.graph_conv2([x, a])
        # Use i in the global pooling layer if necessary
        x = self.pool([x, i])
        return self.classifier(x)

model = GNN()
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
from scipy.sparse import coo_matrix, save_npz
import numpy as np
import pickle
    
def save_graphs_pickle(graphs, filename):
    with open(filename, 'wb') as f:
        pickle.dump(graphs, f, protocol=pickle.HIGHEST_PROTOCOL)

def load_graphs_pickle(filename):
    with open(filename, 'rb') as f:
        graphs = pickle.load(f)
    return graphs

save_graphs_pickle(graphs, '/Users/admin/kaggle/belka/data/belka_graph_data.pickle')

# %%
graphs = load_graphs_pickle('/Users/admin/kaggle/belka/data/belka_graph_data.pickle')
train_graphs, val_graphs = train_test_split(graphs, test_size=0.2, random_state=42)
train_dataset = MoleculeDataset(train_graphs)
val_dataset = MoleculeDataset(val_graphs)
train_loader = DisjointLoader(train_dataset, node_level=True, batch_size=32, shuffle=False)
val_loader = DisjointLoader(val_dataset, node_level=True, batch_size=32, shuffle=False)

# %%
# Assuming 'loader' is your DisjointLoader instance
# model.fit(loader.load(), steps_per_epoch=loader.steps_per_epoch, epochs=10, verbose=1)
model.fit(train_loader.load(),
          validation_data=val_loader.load(),
          steps_per_epoch=train_loader.steps_per_epoch,
          validation_steps=val_loader.steps_per_epoch,
          epochs=10,
          verbose=1)
# Out:
# Epoch 1/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9989 - loss: 0.0088 - val_accuracy: 0.9985 - val_loss: 0.0115
# Epoch 2/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9989 - loss: 0.0088 - val_accuracy: 0.9985 - val_loss: 0.0115
# Epoch 3/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9989 - loss: 0.0088 - val_accuracy: 0.9985 - val_loss: 0.0115
# Epoch 4/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9989 - loss: 0.0088 - val_accuracy: 0.9985 - val_loss: 0.0115
# Epoch 5/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9989 - loss: 0.0088 - val_accuracy: 0.9985 - val_loss: 0.0115
# Epoch 6/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9989 - loss: 0.0088 - val_accuracy: 0.9985 - val_loss: 0.0115
# Epoch 7/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9989 - loss: 0.0088 - val_accuracy: 0.9985 - val_loss: 0.0115
# Epoch 8/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9989 - loss: 0.0088 - val_accuracy: 0.9985 - val_loss: 0.0115
# Epoch 9/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9989 - loss: 0.0088 - val_accuracy: 0.9985 - val_loss: 0.0115
# Epoch 10/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9989 - loss: 0.0088 - val_accuracy: 0.9985 - val_loss: 0.0115

# %% [markdown]
# ### Tune Hyperparameters

# %%
from ray import tune
from ray.tune.schedulers import ASHAScheduler
from sklearn.model_selection import train_test_split

def train_gnn(config, checkpoint_dir=None):
    from spektral.data import DisjointLoader
    
    graphs = load_graphs_pickle('/Users/admin/kaggle/belka/data/belka_graph_data.pickle')
    train_graphs, val_graphs = train_test_split(graphs, test_size=0.2, random_state=42)
    train_dataset = MoleculeDataset(train_graphs)
    val_dataset = MoleculeDataset(val_graphs)
    train_loader = DisjointLoader(train_dataset, node_level=True, batch_size=32, shuffle=False)
    val_loader = DisjointLoader(val_dataset, node_level=True, batch_size=32, shuffle=False)

    model = GNN(activation=config['activation'])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    callback = tf.keras.callbacks.TensorBoard(log_dir='./logs')
    history = model.fit(train_loader.load(),
                        validation_data=val_loader.load(),
                        epochs=config['num_epochs'],
                        callbacks=[callback],
                        steps_per_epoch=train_loader.steps_per_epoch,
                        validation_steps=val_loader.steps_per_epoch,
                        verbose=1)

    loss = history.history['loss'][-1]
    train.report({'loss': loss})


scheduler = ASHAScheduler(
    metric="loss",
    mode="min",
    max_t=50,
    grace_period=10,
    reduction_factor=2
)

config = {
    "lr": tune.loguniform(1e-4, 1e-1),
    "dropout_rate": tune.uniform(0.1, 0.5),
    "activation": tune.choice(['relu', 'tanh', 'sigmoid', 'leaky_relu']),
    "num_epochs": tune.choice([10, 20, 30])
}

result = tune.run(
    tune.with_parameters(train_gnn),
    config=config,
    num_samples=10,
    resources_per_trial={"cpu": 1, "gpu": 0},
    scheduler=scheduler,
    progress_reporter=tune.CLIReporter(metric_columns=["loss", "training_iteration"])
)

best_trial = result.get_best_trial("loss", "min", "last")
print("Best trial config: {}".format(best_trial.config))
print("Best trial final validation loss: {}".format(best_trial.last_result["loss"]))
# Out:
# 2024-05-01 11:32:04,459	INFO tune.py:624 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# == Status ==
# Current time: 2024-05-01 11:32:04 (running for 00:00:00.18)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 PENDING)
#
#
# == Status ==
# Current time: 2024-05-01 11:32:09 (running for 00:00:05.24)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:32:14 (running for 00:00:10.34)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:32:19 (running for 00:00:15.44)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:32:25 (running for 00:00:20.53)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:32:30 (running for 00:00:25.61)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:32:35 (running for 00:00:30.70)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:32:40 (running for 00:00:35.78)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:32:45 (running for 00:00:40.87)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:32:50 (running for 00:00:45.97)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:32:55 (running for 00:00:51.06)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:33:00 (running for 00:00:56.16)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:33:05 (running for 00:01:01.25)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:33:10 (running for 00:01:06.34)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:33:15 (running for 00:01:11.34)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:33:20 (running for 00:01:16.43)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:33:25 (running for 00:01:21.51)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:33:30 (running for 00:01:26.52)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:33:36 (running for 00:01:31.61)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:33:41 (running for 00:01:36.70)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:33:46 (running for 00:01:41.79)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:33:51 (running for 00:01:46.79)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:33:56 (running for 00:01:51.80)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:34:01 (running for 00:01:56.89)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:34:06 (running for 00:02:01.98)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:34:11 (running for 00:02:07.07)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:34:16 (running for 00:02:12.16)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:34:21 (running for 00:02:17.25)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:34:26 (running for 00:02:22.27)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:34:31 (running for 00:02:27.28)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:34:36 (running for 00:02:32.38)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:34:41 (running for 00:02:37.46)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:34:47 (running for 00:02:42.55)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:34:52 (running for 00:02:47.56)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:34:57 (running for 00:02:52.66)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:35:02 (running for 00:02:57.75)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:35:07 (running for 00:03:02.84)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:35:12 (running for 00:03:07.84)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:35:17 (running for 00:03:12.94)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:35:22 (running for 00:03:18.04)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:35:27 (running for 00:03:23.06)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:35:32 (running for 00:03:28.06)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:35:37 (running for 00:03:33.16)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:35:42 (running for 00:03:38.24)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:35:47 (running for 00:03:43.34)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:35:52 (running for 00:03:48.44)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:35:57 (running for 00:03:53.45)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:36:03 (running for 00:03:58.56)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:36:08 (running for 00:04:03.57)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:36:13 (running for 00:04:08.65)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:36:18 (running for 00:04:13.76)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:36:23 (running for 00:04:18.85)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:36:28 (running for 00:04:23.87)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:36:33 (running for 00:04:28.97)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:36:38 (running for 00:04:34.06)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:36:43 (running for 00:04:39.16)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:36:48 (running for 00:04:44.16)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:36:53 (running for 00:04:49.26)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:36:58 (running for 00:04:54.36)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:37:03 (running for 00:04:59.45)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:37:08 (running for 00:05:04.45)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:37:14 (running for 00:05:09.53)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:37:19 (running for 00:05:14.61)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:37:24 (running for 00:05:19.71)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:37:29 (running for 00:05:24.80)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:37:34 (running for 00:05:29.81)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:37:39 (running for 00:05:34.81)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:37:44 (running for 00:05:39.83)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:37:49 (running for 00:05:44.84)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:37:54 (running for 00:05:49.93)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:37:59 (running for 00:05:54.94)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:38:04 (running for 00:05:59.95)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:38:09 (running for 00:06:04.96)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:38:14 (running for 00:06:10.04)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:38:19 (running for 00:06:15.14)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:38:24 (running for 00:06:20.22)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:38:29 (running for 00:06:25.32)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:38:34 (running for 00:06:30.42)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:38:39 (running for 00:06:35.51)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:38:44 (running for 00:06:40.52)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:38:50 (running for 00:06:45.61)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:38:55 (running for 00:06:50.68)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:39:00 (running for 00:06:55.69)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:39:05 (running for 00:07:00.79)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:39:10 (running for 00:07:05.89)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:39:15 (running for 00:07:10.99)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:39:20 (running for 00:07:15.99)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:39:25 (running for 00:07:21.08)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:39:30 (running for 00:07:26.09)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:39:35 (running for 00:07:31.18)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:39:40 (running for 00:07:36.18)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:39:45 (running for 00:07:41.26)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:39:50 (running for 00:07:46.35)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:39:55 (running for 00:07:51.45)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:40:01 (running for 00:07:56.55)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:40:06 (running for 00:08:01.64)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:40:11 (running for 00:08:06.65)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:40:16 (running for 00:08:11.69)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:40:21 (running for 00:08:16.70)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:40:26 (running for 00:08:21.79)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:40:31 (running for 00:08:26.82)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:40:36 (running for 00:08:31.91)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:40:41 (running for 00:08:37.01)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:40:46 (running for 00:08:42.10)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:40:51 (running for 00:08:47.12)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:40:56 (running for 00:08:52.12)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:41:01 (running for 00:08:57.22)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:41:06 (running for 00:09:02.31)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:41:11 (running for 00:09:07.33)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:41:16 (running for 00:09:12.43)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:41:21 (running for 00:09:17.44)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:41:26 (running for 00:09:22.52)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:41:32 (running for 00:09:27.52)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:41:37 (running for 00:09:32.52)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:41:42 (running for 00:09:37.53)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:41:47 (running for 00:09:42.62)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:41:52 (running for 00:09:47.71)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:41:57 (running for 00:09:52.80)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:42:02 (running for 00:09:57.82)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# ...
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:53:10 (running for 00:21:05.86)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:53:15 (running for 00:21:10.94)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:53:20 (running for 00:21:16.01)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:53:25 (running for 00:21:21.10)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:53:30 (running for 00:21:26.17)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:53:35 (running for 00:21:31.23)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:53:40 (running for 00:21:36.33)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:53:45 (running for 00:21:41.40)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:53:50 (running for 00:21:46.48)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:53:56 (running for 00:21:51.57)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:54:01 (running for 00:21:56.63)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:54:06 (running for 00:22:01.69)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:54:11 (running for 00:22:06.69)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:54:16 (running for 00:22:11.79)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:54:21 (running for 00:22:16.86)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:54:26 (running for 00:22:21.96)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:54:31 (running for 00:22:27.04)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:54:36 (running for 00:22:32.12)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:54:41 (running for 00:22:37.19)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:54:46 (running for 00:22:42.21)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:54:51 (running for 00:22:47.29)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:54:56 (running for 00:22:52.29)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:55:01 (running for 00:22:57.40)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:55:06 (running for 00:23:02.40)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:55:11 (running for 00:23:07.50)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:55:17 (running for 00:23:12.61)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:55:22 (running for 00:23:17.70)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:55:27 (running for 00:23:22.71)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-01 11:55:32 (running for 00:23:27.73)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
# 2024-05-01 11:55:36,915	WARNING tune.py:229 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.
# 2024-05-01 11:55:36,926	WARNING experiment_state.py:205 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this error by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0).
# 2024-05-01 11:55:36,930	INFO tune.py:1021 -- Wrote the latest version of all result files and experiment state to '/Users/admin/ray_results/train_gnn_2024-05-01_11-32-04' in 0.0117s.
# == Status ==
# Current time: 2024-05-01 11:55:36 (running for 00:23:32.45)
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 40.000: None | Iter 20.000: None | Iter 10.000: None
# Logical resource usage: 10.0/14 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/session_2024-05-01_10-41-20_376415_1121/artifacts/2024-05-01_11-32-04/train_gnn_2024-05-01_11-32-04/driver_artifacts
# Number of trials: 10/10 (10 RUNNING)
# +-----------------------+----------+----------------+--------------+----------------+-------------+--------------+
# | Trial name            | status   | loc            | activation   |   dropout_rate |          lr |   num_epochs |
# |-----------------------+----------+----------------+--------------+----------------+-------------+--------------|
# | train_gnn_1bab6_00000 | RUNNING  | 127.0.0.1:6455 | tanh         |       0.489718 | 0.000126517 |           20 |
# | train_gnn_1bab6_00001 | RUNNING  | 127.0.0.1:6456 | leaky_relu   |       0.241048 | 0.00993345  |           20 |
# | train_gnn_1bab6_00002 | RUNNING  | 127.0.0.1:6457 | leaky_relu   |       0.300582 | 0.000349581 |           20 |
# | train_gnn_1bab6_00003 | RUNNING  | 127.0.0.1:6458 | leaky_relu   |       0.277839 | 0.000129408 |           10 |
# | train_gnn_1bab6_00004 | RUNNING  | 127.0.0.1:6459 | relu         |       0.149776 | 0.065596    |           10 |
# | train_gnn_1bab6_00005 | RUNNING  | 127.0.0.1:6460 | relu         |       0.42868  | 0.0225325   |           10 |
# | train_gnn_1bab6_00006 | RUNNING  | 127.0.0.1:6461 | tanh         |       0.250802 | 0.00130062  |           10 |
# | train_gnn_1bab6_00007 | RUNNING  | 127.0.0.1:6462 | leaky_relu   |       0.241442 | 0.000272703 |           20 |
# | train_gnn_1bab6_00008 | RUNNING  | 127.0.0.1:6463 | relu         |       0.421185 | 0.000433323 |           30 |
# | train_gnn_1bab6_00009 | RUNNING  | 127.0.0.1:6464 | tanh         |       0.447281 | 0.00224884  |           20 |
# +-----------------------+----------+----------------+--------------+----------------+-------------+--------------+
# 2024-05-01 11:55:47,001	INFO tune.py:1053 -- Total run time: 1422.54 seconds (1412.44 seconds for the tuning loop).
# 2024-05-01 11:55:47,002	WARNING tune.py:1068 -- Experiment has been interrupted, but the most recent state was saved.
# Resume experiment with: tune.run(..., resume=True)
# 2024-05-01 11:55:47,006	WARNING experiment_analysis.py:568 -- Could not find best trial. Did you pass the correct `metric` parameter?
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[93], line 56
#      46 result = tune.run(
#      47     tune.with_parameters(train_gnn),
#      48     config=config,
#    (...)
#      52     progress_reporter=tune.CLIReporter(metric_columns=["loss", "training_iteration"])
#      53 )
#      55 best_trial = result.get_best_trial("loss", "min", "last")
# ---> 56 print("Best trial config: {}".format(best_trial.config))
#      57 print("Best trial final validation loss: {}".format(best_trial.last_result["loss"]))
#
# AttributeError: 'NoneType' object has no attribute 'config'
